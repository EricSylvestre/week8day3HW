# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./marathon_results_2017 - marathon_results_2017.csv')

# %%
#1. Display runner data for all runners with an official time of 2:25:00 or better.

df[df['Official Time'] <= '2:25:00']
# Out:
#     Unnamed: 0  Bib                      Name  Age M/F              City  \
# 0            0   11           Kirui, Geoffrey   24   M          Keringet
# 1            1   17               Rupp, Galen   30   M          Portland
# 2            2   23             Osako, Suguru   25   M      Machida-City
# 3            3   21          Biwott, Shadrack   32   M     Mammoth Lakes
# 4            4    9            Chebet, Wilson   31   M          Marakwet
# 5            5   15          Abdirahman, Abdi   40   M           Phoenix
# 6            6   63        Maiyo, Augustus K.   33   M  Colorado Springs
# 7            7    7               Sefir, Dino   28   M       Addis Ababa
# 8            8   18            Puskedra, Luke   27   M            Eugene
# 9            9   20               Ward, Jared   28   M         Kaysville
# 10          10   22             Quigley, Sean   32   M         Braintree
# 11          11    6            Tsegay, Yemane   32   M       Addis Ababa
# ...

# %%
#2. Display all runners from Boston

boston_runners = df[df["City"] == "Boston"]

df_boston = pd.DataFrame(boston_runners)

df_boston
# Out:
#        Unnamed: 0    Bib                  Name  Age M/F    City State Country  \
# 19             19     31         Harvey, Brian   29   M  Boston    MA     USA
# 27             27     28            Ashe, Eric   28   M  Boston    MA     USA
# 65             65    248        Gilmore, Peter   27   M  Boston    MA     USA
# 82             82    205       Klecker, Jack R   25   M  Boston    MA     USA
# 174           174    281    Pierce, Clayton J.   25   M  Boston    MA     USA
# ...           ...    ...                   ...  ...  ..     ...   ...     ...
# 26295       26295  27154     LeBlanc, Erica R.   24   F  Boston    MA     USA
# 26320       26320  30010  Sulpizio, Rebecca K.   23   F  Boston    MA     USA
# 26332       26332  30269      Enista, Katie M.   32   F  Boston    MA     USA
# 26385       26385  26889    Welch, Jennifer E.   37   F  Boston    MA     USA
# 26392       26392  10603       Ferry, J. Alain   45   M  Boston    MA     USA
#
# ...

# %%
#3. What was the average age of all the runners?

df['Age'].mean()
# Out:
# 42.587731919727375
